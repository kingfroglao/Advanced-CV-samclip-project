# %%
# !pip install transformers timm

# %%
import sys
import os

# --- 步骤 1: 确定我们正确的 Python 路径 ---
python_executable_path = sys.executable

print(f"--- 诊断信息 ---")
print(f"你的 Notebook 内核 (Kernel) 正在使用这个 Python 解释器:")
print(python_executable_path)
print(f"我们将强制使用 *这个* 解释器来安装和运行。")
print("-" * 20)


# --- 步骤 2: 强制在正确的环境中安装 CLIP ---
# print(f"\n--- 步骤 2: 正在强制重新安装 'clip' 到这个环境中... ---")
# install_command = f'"{python_executable_path}" -m pip install --force-reinstall --no-cache-dir git+https://github.com/openai/CLIP.git'
# print(f"执行命令: {install_command}")
# os.system(install_command)
# print("--- 'clip' 安装命令执行完毕 ---")

# %%
# --- 步骤 3: 使用正确的环境运行你的脚本 ---
print(f"\n--- 步骤 3: 正在使用正确的 Python 解释器运行 'modelpart2.py'... ---")
# run_command = f'"{python_executable_path}" modelpart2.py'
run_command = f'"{python_executable_path}" eval_gd.py'
print(f"执行命令: {run_command}")
os.system(run_command)
print("\n--- 脚本执行完毕 ---")

# %%
# !nvidia-smi
# Out:
# Wed Nov  5 06:13:16 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX A4000               On  |   00000000:46:00.0 Off |                  Off |
# | 82%   91C    P0            110W /  140W |   13597MiB /  16376MiB |     45%      Default |
# |                                         |                        |                  N/A |
# ...
