# %%
# import sys
# !{sys.executable} -m pip install datasets Pillow

# %%
# !python3 dataloader.py
# Out:
# --- 正在测试 RefCOCO Dataloader (Hugging Face 版本) ---
# --- 正在使用 Hugging Face 加载 'lmms-lab/RefCOCO' (Split: val) ---
# 找到了 8811 个样本。正在转换格式并清理数据...
# 处理 val: 100%|████████████████████████████| 8811/8811 [00:38<00:00, 231.21it/s]
# --- Dataloader 加载完毕。成功加载 8811 / 8811 个样本 ---
#
# --- 测试成功 ---
# 总共加载了 8811 个样本。
#
# 第一个样本 (Example):
#   Image ID: COCO_train2014_000000580957_4.jpg
#   Text Prompt: "bowl behind the others can only see part"
#   Image Shape: (428, 640, 3)
#   GT Mask Shape: (428, 640)
#   GT Mask Type: bool
#   蒙版中 'True' 的像素点数量: 17897

# %%
# !{sys.executable} eval.py
# Out:
# 1303.90s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# --- 评估脚本启动 ---
# 注意: 评估将限制在 20 个样本上。
#
# --- 正在加载模型... ---
# 正在加载 SAM 模型 'vit_b' (Small Version) 到设备: cuda...
# SAM checkpoint 'sam_vit_b_01ec64.pth' (vit_b) 已存在。
# SAM Automatic Mask Generator (vit_b) 加载成功。
# 正在加载 CLIP 模型 'ViT-B/32' 到设备: cuda...
# CLIP 模型加载成功。
#
# --- 正在加载 RefCOCO 'val' split... ---
# --- 正在使用 Hugging Face 加载 'lmms-lab/RefCOCO' (Split: val) ---
# 找到了 8811 个样本。正在转换格式并清理数据...
# 处理 val: 100%|████████████████████████████| 8811/8811 [00:37<00:00, 236.29it/s]
# --- Dataloader 加载完毕。成功加载 8811 / 8811 个样本 ---
#
# --- 开始评估 20 个样本... ---
# 当前 mIoU: 0.1104: 100%|████████████████████████| 20/20 [05:24<00:00, 16.22s/it]
#
# --- 评估完成 ---
#
# 在 20 个样本上的最终 mIoU: 0.1104
